# %% [markdown]
# ## Bibliotecas

# %%
# !pip install mip

import pandas as pd
import random
import math
import time
from mip import Model, xsum, maximize, BINARY, INTEGER, OptimizationStatus
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mip in /home/gabi/.local/lib/python3.11/site-packages (1.15.0)
# Requirement already satisfied: cffi==1.15.* in /usr/lib64/python3.11/site-packages (from mip) (1.15.1)
# Requirement already satisfied: pycparser in /usr/lib/python3.11/site-packages (from cffi==1.15.*->mip) (2.20)
# Requirement already satisfied: ply==3.11 in /usr/lib/python3.11/site-packages (from pycparser->cffi==1.15.*->mip) (3.11)

# %% [markdown]
# # Leitura dos Dados

# %%
# Função para ler e processar os dados dos monitores e disciplinas a partir de um arquivo Excel.
# Ela lê o arquivo, limpa os nomes das colunas, remove duplicatas e extrai as colunas relevantes.
# Retorna um dicionário de alunos, uma lista de notas (Na) e uma matriz de disponibilidade (s_ad).
# Parâmetro:
# - path (str): Caminho para o arquivo Excel.
# Retornos:
# - alunos (dict): Dicionário onde a chave é o número USP e contem as seguintes informacoes --
#  -- > [Interesse em ser voluntario(ignorar), pontuacao do aluno (float), criterio de desempate (1, 2 ou 3), lista de materias que ele esta inscrito (Ex: [38, 39, 40]]).
# - Na (list): Lista das notas dos alunos.
# - s_ad (list of lists): Matriz binária de disponibilidade dos alunos para disciplinas.
def ler_dados(path):
    # Padroniza o nome das colunas, para facilitar extracao
    def limpar_nome_coluna(nome):
        return ' '.join(nome.strip().split()).lower()

    # Le e extrai as colunas necessarias
    df = pd.read_excel(path)
    df.columns = [limpar_nome_coluna(col) for col in df.columns]
    df = df.drop_duplicates(subset=['nºusp'], keep='last') # mantem apenas a ultima ocorrencia de um NUSP

    colunas_n = [
        'nºusp',
        'possui pedido de bolsa de estudos em andamento? (a concessão de bolsa de estudos implicará no cancelamento da monitoria a partir do início da vigência da bolsa)',
        'pretende se inscrever no peeg? (o acúmulo das duas monitorias não é permitido. caso o aluno seja selecionado nas duas modalidades precisará optar por uma delas)',
        'departamento de matemática (início da monitoria em 05/08/2024)',
        'departamento de matemática aplicada e estatística (início da monitoria em 05/08/2024)',
        'departamento de ciências de computação (início da monitoria em 05/08/2024)',
        'departamento de sistemas de computação (início da monitoria em 01/09/2024)',
        'tem interesse na monitoria voluntária (sem recebimento de bolsa)?',
        'média ponderada com reprovações'
    ]

    df_colunas = df[colunas_n].copy()

    # Calcula a pontuacao para criterio de desempate dos alunos (3 - mais prioridade, 2 - prioridade media, 1 - prioridade baixa)
    def calcular_pontuacao(row):
        bolsa = row[colunas_n[1]]
        peeg = row[colunas_n[2]]
        if bolsa == 'Sim' and peeg == 'Sim':
            return 1
        elif bolsa == 'Não' and peeg == 'Não':
            return 3
        return 2

    df_colunas['bolsa_peeg_status'] = df_colunas.apply(calcular_pontuacao, axis=1)
    df_colunas = df_colunas.drop([colunas_n[1], colunas_n[2]], axis=1)

    # Faz o mapeamento dos departamentos presentes na planilha
    departamento_mapping = {
        colunas_n[3]: 1,
        colunas_n[4]: 2,
        colunas_n[5]: 3,
        colunas_n[6]: 4
    }

    # Extrai as materias presentes na planilha
    materias_set = set()
    materias_dict = {}
    materia_index = 0

    for dept_col, dept_num in departamento_mapping.items():
        for materias in df_colunas[dept_col].dropna():
            for materia in materias.split(','):
                materia = materia.strip()
                if materia not in materias_set:
                    materias_set.add(materia)
                    materias_dict[materia_index] = (materia, dept_num)
                    materia_index += 1

    # Extrai os alunos, sua nota, sua pontuacao de desempate, se tem interesse em ser voluntario e as materias que ele se inscreveu
    alunos = df_colunas.set_index('nºusp').T.to_dict('list')

    Na = []
    for usp, valores in alunos.items():
        materias_combinadas = []
        valores_limpos = []
        for valor in valores:
            if isinstance(valor, str) and '-' in valor:
                for materia in valor.split(','):
                    materia = materia.strip()
                    for indice, (mat, dept) in materias_dict.items():
                        if materia == mat:
                            materias_combinadas.append(indice)
                            break
            elif isinstance(valor, str) and (valor.upper() == 'POS' or valor.upper() == 'PÓS'): # atribui a nota 1 caso o aluno for da pos, para diminuir sua prioridade
                valores_limpos.append(1)
            elif not pd.isna(valor):
                valores_limpos.append(valor)

        if materias_combinadas:
            valores_limpos.append(sorted(materias_combinadas))

        alunos[usp] = valores_limpos
        nota = valores_limpos[1] if len(valores_limpos) > 1 else None
        Na.append(nota)

    s_ad = [
        [1 if materia in valores_limpos[-1] else 0 for materia in materias_dict.keys()]
        for usp, valores_limpos in alunos.items()
    ]

    return alunos, Na, s_ad

# %% [markdown]
# # Modelo

# %%
# Função para criar o modelo de otimização de alocação de monitores com base nos dados fornecidos.
# Parâmetros:
# - alunos (dict): Dicionário de alunos (informações como notas, disponibilidade etc).
# - Na (list): Lista de notas dos alunos.
# - s_ad (list of lists): Matriz de disponibilidade dos alunos para disciplinas.
# - materias (list): Lista de todas as disciplinas.
# Retorno: Deve retornar o modelo de otimização, variáveis e os dados para análise posterior.
def criar_modelo(alunos, Na, s_ad, materias):
    A = list(range(len(alunos)))  # Conjunto de monitores
    D = list(range(len(materias)))  # Conjunto de disciplinas

    # Criação do modelo
    m = Model("Alocacao_de_Monitores", solver_name="CBC")

    # Variáveis de decisão
    x_ad = [[m.add_var(var_type=BINARY) for d in D] for a in A]  # x_ad[a][d]: 1 se monitor 'a' é alocado à disciplina 'd'
    y_d = [m.add_var(var_type=BINARY) for d in D]  # y_d[d]: 1 se disciplina 'd' não possui monitor
    # teste computacional 7
    # Extração do critério de desempate dos alunos
    desempate = [alunos[usp][2] if len(alunos[usp]) > 2 else 1 for usp in alunos]  # Padrão: 1 (baixa prioridade)
    # Definição do valor de Big M
    M = 1e-3  # Pequeno o suficiente para não alterar significativamente a solução
    #Função objetivo para teste computacional 7
    m.objective = maximize(
        xsum(Na[a] * x_ad[a][d] for a in A for d in D)  # Prioridade principal
        + M * xsum(desempate[a] * x_ad[a][d] for a in A for d in D)  # Peso secundário ajustado
        - xsum(y_d[d] for d in D)  # Penalidade para disciplinas sem monitor
    )
    # # Função objetivo
    # m.objective = maximize(
    #     xsum(Na[a] * x_ad[a][d] for a in A for d in D) - xsum(y_d[d] for d in D)
    # )

    # Restrições
    for d in D:
        m += xsum(x_ad[a][d] for a in A) + y_d[d] == 1  # Cada disciplina deve ter, no máximo, um monitor ou ficar sem monitor
    for a in A:
        m += xsum(x_ad[a][d] for d in D) <= 1  # Cada monitor pode ser alocado a, no máximo, uma disciplina
    for a in A:
        for d in D:
            m += x_ad[a][d] <= s_ad[a][d]  # Monitor só pode ser alocado a disciplinas que ele indicou interesse
    #teste computacional 3
    # monitores_disponiveis = A.copy()
    # disciplinas_disponiveis = D.copy()
    # alocacoes_fixadas = 0

    # for a in monitores_disponiveis.copy():
    #     disciplinas_compativeis = [d for d in disciplinas_disponiveis if s_ad[a][d] == 1]
    #     if disciplinas_compativeis:
    #         d = disciplinas_compativeis[0]  # Select the first compatible discipline
    #         x_ad[a][d].lb = 1  # Fix the variable to 1
    #         x_ad[a][d].ub = 1
    #         monitores_disponiveis.remove(a)
    #         disciplinas_disponiveis.remove(d)
    #         alocacoes_fixadas += 1
    #         if alocacoes_fixadas == 5:
    #             break
    return m, x_ad, y_d, D

# Função para resolver o modelo de otimização com base em parâmetros fornecidos.
# Parâmetros:
# - modelo (pulp.LpProblem): O modelo de otimização que será resolvido.
# - presolve (int): Se 1, presolve é ativado; se 0, é desativado.
# - cortes (int): Intensidade da geracao de cortes (0 desativa).
# Retorno: O modelo resolvido.
def resolver_modelo(modelo, presolve, cortes):
    # Configurar as opções do solver
    #teste computacional 6- comentar #modelo.preprocess = presolve 
    modelo.preprocess = presolve  # Define preprocess (-1, 0, 1)
    #teste computacional 5- comentar #modelo.cuts = cortes
    modelo.cuts = cortes  # Define geração de cortes (-1, 0, 1, 2, 3)  
    # Medir o tempo de execução
    start_time = time.time()

    # Resolver o modelo
    status = modelo.optimize(max_seconds=1800) # Limite de tempo de 30 minutos

    # Calcular o tempo de execução
    execution_time = time.time() - start_time

    # Exibir as informações do modelo resolvido
    print(f"Solução Encontrada: {modelo.objective_value}")
    print(f"Gap: {modelo.gap * 100:.2f}%")
    print(f"Tempo de execução: {execution_time:.2f} segundos")

    return modelo

# Função para exibir as informações dos monitores alocados e não alocados, além das disciplinas não atendidas.
# Parâmetros:
# - m (pulp.LpProblem): O modelo de otimização resolvido.
# - x_ad (dict): Variáveis de decisão indicando a alocação dos monitores às disciplinas.
# - y_d (dict): Variáveis de decisão indicando disciplinas não atendidas.
# - alunos (dict): Dicionário contendo as informações dos alunos.
# - D (list): Lista de disciplinas disponíveis.
# - s_ad (list of lists): Matriz de disponibilidade dos monitores para as disciplinas.
# Retorno: Nenhum. A função imprime os resultados diretamente.
def informacoes_monitores(m, x_ad, y_d, alunos, D, s_ad):
    monitores_alocados = []
    monitores_nao_alocados = []

    # Exibe os monitores alocados para disciplinas
    for a in range(len(alunos)):
        alocado = False
        for d in D:
            if x_ad[a][d].x >= 0.99:  # Verifica se a variável é 1
                monitores_alocados.append(f"Monitor {list(alunos.keys())[a]} foi alocado para a disciplina {d}.")
                alocado = True

        # Caso o monitor não tenha sido alocado, armazenar a informação para exibir depois
        if not alocado:
            disciplinas_inscrito = [d for d in D if s_ad[a][d] == 1]
            monitores_nao_alocados.append(f"Monitor {list(alunos.keys())[a]} NÃO foi alocado. Inscrito para as disciplinas: {disciplinas_inscrito}")

    # Exibir os monitores alocados
    print("\nMonitores alocados:")
    for alocacao in monitores_alocados:
        print(alocacao)

    # Exibir os monitores não alocados
    print("\nMonitores não alocados:")
    for nao_alocacao in monitores_nao_alocados:
        print(nao_alocacao)

    # Mostrar disciplinas não atendidas e os monitores que se inscreveram para elas
    print("\nDisciplinas não atendidas e seus inscritos:")
    for d in D:
        if y_d[d].x >= 0.99:  # Verifica se a variável é 1
            monitores_inscritos = [list(alunos.keys())[a] for a in range(len(alunos)) if s_ad[a][d] == 1]
            if monitores_inscritos:
                print(f"A disciplina {d} não foi atendida por nenhum monitor. Inscritos: {monitores_inscritos}")
            else:
                print(f"A disciplina {d} não foi atendida por nenhum monitor e não possui inscritos.")

# %% [markdown]
# # Gerar Instâncias Maiores

# %%
# Função para aumentar os dados de alunos e matérias com base na escala fornecida.
# Parâmetros:
# - file_path (str): Caminho para o arquivo Excel com os dados originais.
# - escala (float): Fator de aumento dos dados (e.g., 1.5 para aumentar em 50%).
# Retorno: Retorna os dados aumentados (alunos, notas, disponibilidade dos alunos para disciplinas e a lista de matérias).
def aumentar_dados(path, escala):
    # Lê os dados originais usando a função existente
    alunos_originais, Na_originais, s_ad_originais = ler_dados(path)
    seed = 0

    # Se seed for 0 e escala for 1, retornar os dados originais
    if seed == 0 and escala == 1:
        todas_materias = list(range(len(s_ad_originais[0])))
        return alunos_originais, Na_originais, s_ad_originais, todas_materias

    # Define a seed para a geração de dados aleatórios
    if seed is not None:
        random.seed(seed)

    novos_alunos = {}
    novas_notas = []
    nova_s_ad = []
    usp_existentes = set(alunos_originais.keys())
    max_usp = max(usp_existentes)

    # Aumenta o número de materias em 1.12x com base na escala
    num_materias_originais = len(s_ad_originais[0])
    num_novas_materias = math.ceil(num_materias_originais * 1.12 * escala)

    # Novos índices para as matérias que serão adicionadas
    novas_materias = list(range(num_materias_originais, num_materias_originais + num_novas_materias))

    # Aumenta o numero de alunos conforme a escala
    total_alunos = len(alunos_originais)
    num_novos_alunos = math.ceil(total_alunos * (escala - 1))  # Cria novos alunos além dos originais

    # Cria os novos alunos
    for i in range(num_novos_alunos):
        # Novo Nusp
        max_usp += 1
        novo_usp = max_usp
        usp_existentes.add(novo_usp)

        # Gerar uma nova nota aleatória para o novo aluno
        nova_nota = random.uniform(0, 10)
        novas_notas.append(nova_nota)

        # Gerar matérias aleatórias (entre 2 e 4) para cada novo aluno
        num_materias_aluno = random.randint(2, 4)
        todas_materias = list(range(num_materias_originais)) + novas_materias  # Considera matérias antigas e novas
        materias_aluno = random.sample(todas_materias, num_materias_aluno)

        # Criar a matriz de disponibilidade (s_ad) para o novo aluno com as matérias selecionadas
        disponibilidade_aluno = [1 if materia in materias_aluno else 0 for materia in todas_materias]
        nova_s_ad.append(disponibilidade_aluno)

        novos_alunos[novo_usp] = []

    # Expande a matriz s_ad original para acomodar as novas matérias
    s_ad_expandidos = [row + [0] * len(novas_materias) for row in s_ad_originais]
    s_ad_expandidos += nova_s_ad

    # Combinar os dados originais e os novos
    alunos_expandidos = {**alunos_originais, **novos_alunos}
    Na_expandidos = Na_originais + novas_notas

    return alunos_expandidos, Na_expandidos, s_ad_expandidos, todas_materias

# %% [markdown]
# # Exemplo de Uso

# %%
# Caminho do arquivo Excel com os dados originais
path = 'Dados_monitores.xlsx'

# Aumenta os dados de alunos e matérias
#alunos, Na, s_ad, materias = aumentar_dados(path, escala=1)

# teste computacional 4,5, 6 e 7
#alunos, Na, s_ad, materias = aumentar_dados(path, escala=2)
#alunos, Na, s_ad, materias = aumentar_dados(path, escala=3)
#alunos, Na, s_ad, materias = aumentar_dados(path, escala=5)
#alunos, Na, s_ad, materias = aumentar_dados(path, escala=10)
alunos, Na, s_ad, materias = aumentar_dados(path, escala=15)
# Cria o modelo de otimização com os dados aumentados
mod, x_ad, y_d, D = criar_modelo(alunos, Na, s_ad, materias)

# Resolve o modelo
m = resolver_modelo(mod, 1, 1)

informacoes_monitores(m, x_ad, y_d, alunos, D, s_ad)
# Out:
# Welcome to the CBC MILP Solver
# Version: Trunk
# Build Date: Oct 24 2021
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 2375 (-1632712) rows, 5419 (-1628213) columns and 9758 (-4888894) elements
# Clp0030I 21 infeas 0.02822934, obj 6602.058 - mu 6.1277099e-05, its 105, 3296 interior
# Clp0030I 45 infeas 5.5692825e-06, obj 6601.9985 - mu 9.3321284e-09, its 105, 4004 interior
# Clp1000I sum of infeasibilities 0.000165762 - average 6.97945e-08, 1511 fixed columns
# Coin0506I Presolve 2057 (-318) rows, 3694 (-1725) columns and 7216 (-2542) elements
# Clp0006I 0  Obj 6086.1908 Primal inf 0.00011783124 (3) Dual inf 9.0000019e+12 (3619)
# Clp0029I End of values pass after 3619 iterations
# Clp0014I Perturbing problem by 0.001% of 1 - largest nonzero change 2.9936918e-05 ( 0.0014968459%) - largest zero change 2.9976734e-05
# Clp0000I Optimal - objective value 6294.1
# Clp0000I Optimal - objective value 6294.1
# Coin0511I After Postsolve, objective 6294.1, infeasibilities - dual 7.427521 (3), primal 0 (0)
# Coin0512I Presolved model was optimal, full model needs cleaning up
# Clp0006I 0  Obj 6294.1 Dual inf 396.59745 (102)
# Clp0014I Perturbing problem by 0.001% of 1.0014663 - largest nonzero change 2.9976734e-05 ( 0.0014988367%) - largest zero change 2.9936918e-05
# Clp0000I Optimal - objective value 6602.3924
# Clp0000I Optimal - objective value 6602.3924
# Clp0000I Optimal - objective value 6602.3924
# Coin0511I After Postsolve, objective 6602.3924, infeasibilities - dual 11.324354 (3), primal 0 (0)
# Coin0512I Presolved model was optimal, full model needs cleaning up
# Clp0006I 0  Obj 6602.3924 Dual inf 11.324351 (3)
# Clp0006I 200  Obj 6602.3924 Dual inf 40416.418 (30676)
# Clp0006I 400  Obj 6602.3924 Dual inf 310240.24 (172297)
# Clp0006I 600  Obj 6602.3924 Dual inf 66180.623 (44390)
# Clp0006I 800  Obj 6602.3924 Dual inf 39467.744 (30947)
# Clp0006I 1000  Obj 6602.3924 Dual inf 39155.635 (30829)
# Clp0006I 1200  Obj 6602.3924 Dual inf 38806.498 (30697)
# Clp0006I 1400  Obj 6602.3924 Dual inf 6846.5291 (7437)
# Clp0006I 1600  Obj 6602.3924 Dual inf 66.281923 (198)
# Clp0006I 1732  Obj 6602.3924
# Clp0000I Optimal - objective value 6602.3924
# Clp0032I Optimal objective 6602.392433 - 1732 iterations time 49.352, Presolve 5.01, Idiot 1.78
#
# Starting MIP optimization
# Cgl0002I 1627996 variables fixed
# Cgl0004I processed model has 2375 rows, 5419 columns (5419 integer (5419 of which binary)) and 9758 elements
# Coin3009W Conflict graph built in 0.010 seconds, density: 0.047%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 0.279053
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -6602.39
# Cbc0038I Before mini branch and bound, 5419 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (26.64 seconds)
# Cbc0038I After 26.70 seconds - Feasibility pump exiting with objective of -6602.39 - took 0.46 seconds
# Cbc0012I Integer solution of -6602.3924 found by feasibility pump after 0 iterations and 0 nodes (26.73 seconds)
# Cbc0001I Search completed - best objective -6602.392432906387, took 0 iterations and 0 nodes (26.88 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       24.43   (Wallclock seconds):       35.94
#
# Solução Encontrada: 6602.392432906389
# Gap: 0.00%
# Tempo de execução: 94.94 segundos
#
# Monitores alocados:
# Monitor 14590001 foi alocado para a disciplina 19.
# Monitor 14580006 foi alocado para a disciplina 21.
# Monitor 14570008 foi alocado para a disciplina 7.
# Monitor 12540012 foi alocado para a disciplina 47.
# Monitor 14560014 foi alocado para a disciplina 28.
# Monitor 13690016 foi alocado para a disciplina 59.
# Monitor 11210018 foi alocado para a disciplina 0.
# Monitor 10690020 foi alocado para a disciplina 48.
# Monitor 11800021 foi alocado para a disciplina 25.
# Monitor 14550022 foi alocado para a disciplina 40.
# Monitor 89570023 foi alocado para a disciplina 57.
# Monitor 14560015 foi alocado para a disciplina 62.
# Monitor 14710024 foi alocado para a disciplina 29.
# Monitor 13870027 foi alocado para a disciplina 42.
# Monitor 12540029 foi alocado para a disciplina 30.
# Monitor 12620030 foi alocado para a disciplina 20.
# Monitor 14590031 foi alocado para a disciplina 36.
# Monitor 12550033 foi alocado para a disciplina 27.
# Monitor 13670034 foi alocado para a disciplina 56.
# Monitor 13670035 foi alocado para a disciplina 61.
# Monitor 12540036 foi alocado para a disciplina 49.
# Monitor 13680039 foi alocado para a disciplina 34.
# Monitor 13690044 foi alocado para a disciplina 15.
# Monitor 11910046 foi alocado para a disciplina 16.
# Monitor 14610047 foi alocado para a disciplina 23.
# Monitor 14560048 foi alocado para a disciplina 9.
# Monitor 11790052 foi alocado para a disciplina 11.
# Monitor 12550013 foi alocado para a disciplina 24.
# Monitor 14600054 foi alocado para a disciplina 12.
# Monitor 12550055 foi alocado para a disciplina 18.
# Monitor 14600056 foi alocado para a disciplina 55.
# Monitor 11810057 foi alocado para a disciplina 14.
# Monitor 12540058 foi alocado para a disciplina 58.
# Monitor 11800060 foi alocado para a disciplina 22.
# Monitor 13670063 foi alocado para a disciplina 1.
# Monitor 11910064 foi alocado para a disciplina 33.
# Monitor 13830061 foi alocado para a disciplina 51.
# Monitor 55630067 foi alocado para a disciplina 17.
# Monitor 10310070 foi alocado para a disciplina 39.
# Monitor 11840071 foi alocado para a disciplina 54.
# Monitor 11790072 foi alocado para a disciplina 26.
# Monitor 15110073 foi alocado para a disciplina 3.
# Monitor 12680075 foi alocado para a disciplina 37.
# Monitor 10740076 foi alocado para a disciplina 50.
# Monitor 14570078 foi alocado para a disciplina 52.
# Monitor 14560079 foi alocado para a disciplina 4.
# Monitor 13680080 foi alocado para a disciplina 32.
# Monitor 13680081 foi alocado para a disciplina 6.
# Monitor 13830083 foi alocado para a disciplina 38.
# Monitor 10330084 foi alocado para a disciplina 13.
# Monitor 14560087 foi alocado para a disciplina 10.
# Monitor 14570088 foi alocado para a disciplina 8.
# Monitor 14610089 foi alocado para a disciplina 2.
# Monitor 11220090 foi alocado para a disciplina 53.
# Monitor 14750091 foi alocado para a disciplina 41.
# Monitor 12670095 foi alocado para a disciplina 5.
# Monitor 12540096 foi alocado para a disciplina 60.
# Monitor 94220070 foi alocado para a disciplina 1047.
# Monitor 94220071 foi alocado para a disciplina 976.
# Monitor 94220072 foi alocado para a disciplina 286.
# Monitor 94220073 foi alocado para a disciplina 151.
# Monitor 94220074 foi alocado para a disciplina 724.
# Monitor 94220075 foi alocado para a disciplina 1067.
# Monitor 94220077 foi alocado para a disciplina 128.
# Monitor 94220079 foi alocado para a disciplina 655.
# Monitor 94220080 foi alocado para a disciplina 223.
# Monitor 94220081 foi alocado para a disciplina 1106.
# Monitor 94220082 foi alocado para a disciplina 649.
# Monitor 94220083 foi alocado para a disciplina 387.
# Monitor 94220085 foi alocado para a disciplina 306.
# Monitor 94220086 foi alocado para a disciplina 1074.
# Monitor 94220087 foi alocado para a disciplina 858.
# Monitor 94220088 foi alocado para a disciplina 1008.
# Monitor 94220089 foi alocado para a disciplina 996.
# Monitor 94220090 foi alocado para a disciplina 555.
# Monitor 94220092 foi alocado para a disciplina 206.
# Monitor 94220093 foi alocado para a disciplina 92.
# Monitor 94220094 foi alocado para a disciplina 254.
# Monitor 94220095 foi alocado para a disciplina 758.
# Monitor 94220096 foi alocado para a disciplina 74.
# Monitor 94220097 foi alocado para a disciplina 253.
# Monitor 94220099 foi alocado para a disciplina 532.
# Monitor 94220100 foi alocado para a disciplina 717.
# Monitor 94220103 foi alocado para a disciplina 324.
# Monitor 94220104 foi alocado para a disciplina 240.
# Monitor 94220106 foi alocado para a disciplina 513.
# Monitor 94220107 foi alocado para a disciplina 93.
# Monitor 94220109 foi alocado para a disciplina 848.
# Monitor 94220110 foi alocado para a disciplina 393.
# Monitor 94220111 foi alocado para a disciplina 490.
# Monitor 94220112 foi alocado para a disciplina 823.
# Monitor 94220113 foi alocado para a disciplina 912.
# Monitor 94220114 foi alocado para a disciplina 1080.
# Monitor 94220115 foi alocado para a disciplina 79.
# Monitor 94220116 foi alocado para a disciplina 102.
# Monitor 94220117 foi alocado para a disciplina 822.
# Monitor 94220118 foi alocado para a disciplina 437.
# Monitor 94220120 foi alocado para a disciplina 619.
# Monitor 94220122 foi alocado para a disciplina 525.
# Monitor 94220123 foi alocado para a disciplina 710.
# Monitor 94220124 foi alocado para a disciplina 421.
# Monitor 94220125 foi alocado para a disciplina 644.
# Monitor 94220126 foi alocado para a disciplina 762.
# Monitor 94220129 foi alocado para a disciplina 335.
# Monitor 94220132 foi alocado para a disciplina 145.
# Monitor 94220133 foi alocado para a disciplina 985.
# Monitor 94220134 foi alocado para a disciplina 981.
# Monitor 94220135 foi alocado para a disciplina 77.
# Monitor 94220136 foi alocado para a disciplina 769.
# Monitor 94220137 foi alocado para a disciplina 178.
# Monitor 94220138 foi alocado para a disciplina 788.
# Monitor 94220140 foi alocado para a disciplina 866.
# Monitor 94220142 foi alocado para a disciplina 1076.
# Monitor 94220143 foi alocado para a disciplina 243.
# Monitor 94220145 foi alocado para a disciplina 740.
# Monitor 94220146 foi alocado para a disciplina 999.
# Monitor 94220147 foi alocado para a disciplina 1021.
# Monitor 94220148 foi alocado para a disciplina 1111.
# Monitor 94220151 foi alocado para a disciplina 173.
# Monitor 94220152 foi alocado para a disciplina 135.
# Monitor 94220153 foi alocado para a disciplina 918.
# Monitor 94220154 foi alocado para a disciplina 760.
# Monitor 94220155 foi alocado para a disciplina 1028.
# Monitor 94220156 foi alocado para a disciplina 873.
# Monitor 94220158 foi alocado para a disciplina 372.
# Monitor 94220159 foi alocado para a disciplina 521.
# Monitor 94220160 foi alocado para a disciplina 785.
# Monitor 94220163 foi alocado para a disciplina 167.
# Monitor 94220166 foi alocado para a disciplina 663.
# Monitor 94220167 foi alocado para a disciplina 1004.
# Monitor 94220169 foi alocado para a disciplina 606.
# Monitor 94220170 foi alocado para a disciplina 1062.
# Monitor 94220171 foi alocado para a disciplina 932.
# Monitor 94220172 foi alocado para a disciplina 154.
# Monitor 94220175 foi alocado para a disciplina 872.
# Monitor 94220176 foi alocado para a disciplina 172.
# Monitor 94220178 foi alocado para a disciplina 1017.
# Monitor 94220179 foi alocado para a disciplina 144.
# Monitor 94220180 foi alocado para a disciplina 364.
# Monitor 94220182 foi alocado para a disciplina 425.
# Monitor 94220183 foi alocado para a disciplina 252.
# Monitor 94220184 foi alocado para a disciplina 476.
# Monitor 94220186 foi alocado para a disciplina 969.
# Monitor 94220187 foi alocado para a disciplina 210.
# Monitor 94220188 foi alocado para a disciplina 320.
# Monitor 94220189 foi alocado para a disciplina 1041.
# Monitor 94220191 foi alocado para a disciplina 270.
# Monitor 94220192 foi alocado para a disciplina 149.
# Monitor 94220193 foi alocado para a disciplina 726.
# Monitor 94220194 foi alocado para a disciplina 118.
# Monitor 94220195 foi alocado para a disciplina 854.
# Monitor 94220196 foi alocado para a disciplina 600.
# Monitor 94220197 foi alocado para a disciplina 567.
# Monitor 94220198 foi alocado para a disciplina 816.
# Monitor 94220199 foi alocado para a disciplina 928.
# Monitor 94220200 foi alocado para a disciplina 177.
# Monitor 94220201 foi alocado para a disciplina 603.
# Monitor 94220202 foi alocado para a disciplina 447.
# Monitor 94220203 foi alocado para a disciplina 1116.
# Monitor 94220204 foi alocado para a disciplina 189.
# Monitor 94220205 foi alocado para a disciplina 573.
# Monitor 94220207 foi alocado para a disciplina 517.
# Monitor 94220208 foi alocado para a disciplina 401.
# Monitor 94220209 foi alocado para a disciplina 242.
# Monitor 94220210 foi alocado para a disciplina 334.
# Monitor 94220211 foi alocado para a disciplina 1064.
# Monitor 94220212 foi alocado para a disciplina 215.
# Monitor 94220213 foi alocado para a disciplina 905.
# Monitor 94220214 foi alocado para a disciplina 321.
# Monitor 94220215 foi alocado para a disciplina 285.
# Monitor 94220216 foi alocado para a disciplina 1001.
# Monitor 94220217 foi alocado para a disciplina 123.
# Monitor 94220218 foi alocado para a disciplina 107.
# Monitor 94220219 foi alocado para a disciplina 1078.
# Monitor 94220220 foi alocado para a disciplina 809.
# Monitor 94220221 foi alocado para a disciplina 553.
# Monitor 94220222 foi alocado para a disciplina 599.
# Monitor 94220224 foi alocado para a disciplina 303.
# Monitor 94220225 foi alocado para a disciplina 647.
# Monitor 94220227 foi alocado para a disciplina 875.
# Monitor 94220228 foi alocado para a disciplina 899.
# Monitor 94220229 foi alocado para a disciplina 795.
# Monitor 94220232 foi alocado para a disciplina 842.
# Monitor 94220234 foi alocado para a disciplina 441.
# Monitor 94220236 foi alocado para a disciplina 876.
# Monitor 94220237 foi alocado para a disciplina 812.
# Monitor 94220238 foi alocado para a disciplina 175.
# Monitor 94220239 foi alocado para a disciplina 665.
# Monitor 94220240 foi alocado para a disciplina 164.
# Monitor 94220241 foi alocado para a disciplina 708.
# Monitor 94220242 foi alocado para a disciplina 617.
# Monitor 94220243 foi alocado para a disciplina 626.
# Monitor 94220244 foi alocado para a disciplina 943.
# Monitor 94220245 foi alocado para a disciplina 97.
# Monitor 94220246 foi alocado para a disciplina 166.
# Monitor 94220248 foi alocado para a disciplina 874.
# Monitor 94220252 foi alocado para a disciplina 558.
# Monitor 94220253 foi alocado para a disciplina 353.
# Monitor 94220254 foi alocado para a disciplina 582.
# Monitor 94220255 foi alocado para a disciplina 1055.
# Monitor 94220256 foi alocado para a disciplina 787.
# Monitor 94220258 foi alocado para a disciplina 1061.
# Monitor 94220259 foi alocado para a disciplina 983.
# Monitor 94220261 foi alocado para a disciplina 751.
# Monitor 94220262 foi alocado para a disciplina 1045.
# Monitor 94220263 foi alocado para a disciplina 422.
# Monitor 94220264 foi alocado para a disciplina 481.
# Monitor 94220265 foi alocado para a disciplina 1020.
# Monitor 94220266 foi alocado para a disciplina 734.
# Monitor 94220267 foi alocado para a disciplina 450.
# Monitor 94220268 foi alocado para a disciplina 984.
# Monitor 94220269 foi alocado para a disciplina 530.
# Monitor 94220270 foi alocado para a disciplina 597.
# Monitor 94220271 foi alocado para a disciplina 78.
# Monitor 94220272 foi alocado para a disciplina 702.
# Monitor 94220273 foi alocado para a disciplina 462.
# Monitor 94220274 foi alocado para a disciplina 309.
# Monitor 94220275 foi alocado para a disciplina 494.
# Monitor 94220277 foi alocado para a disciplina 865.
# Monitor 94220278 foi alocado para a disciplina 733.
# Monitor 94220280 foi alocado para a disciplina 947.
# Monitor 94220281 foi alocado para a disciplina 350.
# Monitor 94220283 foi alocado para a disciplina 361.
# Monitor 94220284 foi alocado para a disciplina 344.
# Monitor 94220285 foi alocado para a disciplina 307.
# Monitor 94220287 foi alocado para a disciplina 308.
# Monitor 94220288 foi alocado para a disciplina 691.
# Monitor 94220290 foi alocado para a disciplina 960.
# Monitor 94220291 foi alocado para a disciplina 933.
# Monitor 94220292 foi alocado para a disciplina 1015.
# Monitor 94220294 foi alocado para a disciplina 790.
# Monitor 94220297 foi alocado para a disciplina 705.
# Monitor 94220298 foi alocado para a disciplina 1013.
# Monitor 94220299 foi alocado para a disciplina 288.
# Monitor 94220300 foi alocado para a disciplina 257.
# Monitor 94220301 foi alocado para a disciplina 384.
# Monitor 94220302 foi alocado para a disciplina 1084.
# Monitor 94220303 foi alocado para a disciplina 322.
# Monitor 94220304 foi alocado para a disciplina 544.
# Monitor 94220306 foi alocado para a disciplina 884.
# Monitor 94220307 foi alocado para a disciplina 950.
# Monitor 94220308 foi alocado para a disciplina 741.
# Monitor 94220309 foi alocado para a disciplina 398.
# Monitor 94220310 foi alocado para a disciplina 510.
# Monitor 94220311 foi alocado para a disciplina 917.
# Monitor 94220312 foi alocado para a disciplina 205.
# Monitor 94220314 foi alocado para a disciplina 729.
# Monitor 94220316 foi alocado para a disciplina 814.
# Monitor 94220317 foi alocado para a disciplina 952.
# Monitor 94220318 foi alocado para a disciplina 570.
# Monitor 94220319 foi alocado para a disciplina 277.
# Monitor 94220320 foi alocado para a disciplina 142.
# Monitor 94220323 foi alocado para a disciplina 291.
# Monitor 94220324 foi alocado para a disciplina 122.
# Monitor 94220326 foi alocado para a disciplina 369.
# Monitor 94220327 foi alocado para a disciplina 165.
# Monitor 94220328 foi alocado para a disciplina 534.
# Monitor 94220329 foi alocado para a disciplina 934.
# Monitor 94220330 foi alocado para a disciplina 312.
# Monitor 94220331 foi alocado para a disciplina 69.
# Monitor 94220332 foi alocado para a disciplina 395.
# Monitor 94220333 foi alocado para a disciplina 683.
# Monitor 94220334 foi alocado para a disciplina 117.
# Monitor 94220335 foi alocado para a disciplina 163.
# Monitor 94220336 foi alocado para a disciplina 774.
# Monitor 94220337 foi alocado para a disciplina 278.
# Monitor 94220339 foi alocado para a disciplina 90.
# Monitor 94220340 foi alocado para a disciplina 106.
# Monitor 94220341 foi alocado para a disciplina 110.
# Monitor 94220342 foi alocado para a disciplina 523.
# Monitor 94220345 foi alocado para a disciplina 826.
# Monitor 94220346 foi alocado para a disciplina 105.
# Monitor 94220347 foi alocado para a disciplina 537.
# Monitor 94220349 foi alocado para a disciplina 1057.
# Monitor 94220350 foi alocado para a disciplina 75.
# Monitor 94220351 foi alocado para a disciplina 325.
# Monitor 94220352 foi alocado para a disciplina 672.
# Monitor 94220353 foi alocado para a disciplina 492.
# Monitor 94220354 foi alocado para a disciplina 721.
# Monitor 94220356 foi alocado para a disciplina 332.
# Monitor 94220357 foi alocado para a disciplina 304.
# Monitor 94220358 foi alocado para a disciplina 229.
# Monitor 94220359 foi alocado para a disciplina 313.
# Monitor 94220360 foi alocado para a disciplina 893.
# Monitor 94220361 foi alocado para a disciplina 1044.
# Monitor 94220362 foi alocado para a disciplina 835.
# Monitor 94220363 foi alocado para a disciplina 964.
# Monitor 94220364 foi alocado para a disciplina 813.
# Monitor 94220365 foi alocado para a disciplina 516.
# Monitor 94220366 foi alocado para a disciplina 44.
# Monitor 94220367 foi alocado para a disciplina 658.
# Monitor 94220368 foi alocado para a disciplina 1094.
# Monitor 94220370 foi alocado para a disciplina 946.
# Monitor 94220372 foi alocado para a disciplina 1031.
# Monitor 94220373 foi alocado para a disciplina 968.
# Monitor 94220375 foi alocado para a disciplina 596.
# Monitor 94220377 foi alocado para a disciplina 225.
# Monitor 94220378 foi alocado para a disciplina 155.
# Monitor 94220379 foi alocado para a disciplina 283.
# Monitor 94220382 foi alocado para a disciplina 589.
# Monitor 94220383 foi alocado para a disciplina 701.
# Monitor 94220384 foi alocado para a disciplina 480.
# Monitor 94220385 foi alocado para a disciplina 965.
# Monitor 94220386 foi alocado para a disciplina 200.
# Monitor 94220390 foi alocado para a disciplina 519.
# Monitor 94220391 foi alocado para a disciplina 1040.
# Monitor 94220392 foi alocado para a disciplina 837.
# Monitor 94220393 foi alocado para a disciplina 829.
# Monitor 94220395 foi alocado para a disciplina 685.
# Monitor 94220396 foi alocado para a disciplina 80.
# Monitor 94220397 foi alocado para a disciplina 543.
# Monitor 94220398 foi alocado para a disciplina 294.
# Monitor 94220399 foi alocado para a disciplina 805.
# Monitor 94220400 foi alocado para a disciplina 188.
# Monitor 94220402 foi alocado para a disciplina 116.
# Monitor 94220403 foi alocado para a disciplina 406.
# Monitor 94220405 foi alocado para a disciplina 199.
# Monitor 94220407 foi alocado para a disciplina 158.
# Monitor 94220408 foi alocado para a disciplina 780.
# Monitor 94220409 foi alocado para a disciplina 474.
# Monitor 94220410 foi alocado para a disciplina 735.
# Monitor 94220411 foi alocado para a disciplina 727.
# Monitor 94220412 foi alocado para a disciplina 468.
# Monitor 94220413 foi alocado para a disciplina 579.
# Monitor 94220414 foi alocado para a disciplina 315.
# Monitor 94220415 foi alocado para a disciplina 382.
# Monitor 94220416 foi alocado para a disciplina 796.
# Monitor 94220417 foi alocado para a disciplina 451.
# Monitor 94220418 foi alocado para a disciplina 1060.
# Monitor 94220419 foi alocado para a disciplina 966.
# Monitor 94220420 foi alocado para a disciplina 883.
# Monitor 94220421 foi alocado para a disciplina 832.
# Monitor 94220422 foi alocado para a disciplina 370.
# Monitor 94220423 foi alocado para a disciplina 478.
# Monitor 94220426 foi alocado para a disciplina 136.
# Monitor 94220427 foi alocado para a disciplina 782.
# Monitor 94220428 foi alocado para a disciplina 892.
# Monitor 94220429 foi alocado para a disciplina 551.
# Monitor 94220430 foi alocado para a disciplina 275.
# Monitor 94220431 foi alocado para a disciplina 515.
# Monitor 94220432 foi alocado para a disciplina 290.
# Monitor 94220433 foi alocado para a disciplina 654.
# Monitor 94220434 foi alocado para a disciplina 1042.
# Monitor 94220435 foi alocado para a disciplina 365.
# Monitor 94220436 foi alocado para a disciplina 772.
# Monitor 94220437 foi alocado para a disciplina 508.
# Monitor 94220438 foi alocado para a disciplina 915.
# Monitor 94220439 foi alocado para a disciplina 493.
# Monitor 94220440 foi alocado para a disciplina 902.
# Monitor 94220444 foi alocado para a disciplina 343.
# Monitor 94220446 foi alocado para a disciplina 311.
# Monitor 94220447 foi alocado para a disciplina 998.
# Monitor 94220448 foi alocado para a disciplina 402.
# Monitor 94220450 foi alocado para a disciplina 1056.
# Monitor 94220451 foi alocado para a disciplina 692.
# Monitor 94220452 foi alocado para a disciplina 730.
# Monitor 94220453 foi alocado para a disciplina 137.
# Monitor 94220454 foi alocado para a disciplina 807.
# Monitor 94220455 foi alocado para a disciplina 95.
# Monitor 94220457 foi alocado para a disciplina 1107.
# Monitor 94220458 foi alocado para a disciplina 1087.
# Monitor 94220459 foi alocado para a disciplina 1009.
# Monitor 94220461 foi alocado para a disciplina 1049.
# Monitor 94220462 foi alocado para a disciplina 529.
# Monitor 94220464 foi alocado para a disciplina 467.
# Monitor 94220466 foi alocado para a disciplina 238.
# Monitor 94220467 foi alocado para a disciplina 273.
# Monitor 94220468 foi alocado para a disciplina 65.
# Monitor 94220470 foi alocado para a disciplina 1109.
# Monitor 94220471 foi alocado para a disciplina 330.
# Monitor 94220472 foi alocado para a disciplina 704.
# Monitor 94220473 foi alocado para a disciplina 855.
# Monitor 94220474 foi alocado para a disciplina 153.
# Monitor 94220475 foi alocado para a disciplina 262.
# Monitor 94220476 foi alocado para a disciplina 711.
# Monitor 94220477 foi alocado para a disciplina 471.
# Monitor 94220479 foi alocado para a disciplina 1120.
# Monitor 94220480 foi alocado para a disciplina 263.
# Monitor 94220482 foi alocado para a disciplina 598.
# Monitor 94220484 foi alocado para a disciplina 849.
# Monitor 94220485 foi alocado para a disciplina 948.
# Monitor 94220486 foi alocado para a disciplina 607.
# Monitor 94220487 foi alocado para a disciplina 46.
# Monitor 94220488 foi alocado para a disciplina 156.
# Monitor 94220489 foi alocado para a disciplina 588.
# Monitor 94220490 foi alocado para a disciplina 114.
# Monitor 94220491 foi alocado para a disciplina 1091.
# Monitor 94220492 foi alocado para a disciplina 347.
# Monitor 94220493 foi alocado para a disciplina 977.
# Monitor 94220495 foi alocado para a disciplina 896.
# Monitor 94220496 foi alocado para a disciplina 255.
# Monitor 94220497 foi alocado para a disciplina 549.
# Monitor 94220498 foi alocado para a disciplina 731.
# Monitor 94220500 foi alocado para a disciplina 1114.
# Monitor 94220503 foi alocado para a disciplina 409.
# Monitor 94220505 foi alocado para a disciplina 1077.
# Monitor 94220507 foi alocado para a disciplina 497.
# Monitor 94220508 foi alocado para a disciplina 564.
# Monitor 94220509 foi alocado para a disciplina 323.
# Monitor 94220510 foi alocado para a disciplina 109.
# Monitor 94220511 foi alocado para a disciplina 509.
# Monitor 94220512 foi alocado para a disciplina 302.
# Monitor 94220513 foi alocado para a disciplina 608.
# Monitor 94220514 foi alocado para a disciplina 695.
# Monitor 94220515 foi alocado para a disciplina 973.
# Monitor 94220516 foi alocado para a disciplina 779.
# Monitor 94220517 foi alocado para a disciplina 610.
# Monitor 94220518 foi alocado para a disciplina 1053.
# Monitor 94220520 foi alocado para a disciplina 887.
# Monitor 94220521 foi alocado para a disciplina 526.
# Monitor 94220522 foi alocado para a disciplina 412.
# Monitor 94220523 foi alocado para a disciplina 443.
# Monitor 94220524 foi alocado para a disciplina 738.
# Monitor 94220526 foi alocado para a disciplina 743.
# Monitor 94220527 foi alocado para a disciplina 352.
# Monitor 94220530 foi alocado para a disciplina 834.
# Monitor 94220532 foi alocado para a disciplina 694.
# Monitor 94220533 foi alocado para a disciplina 561.
# Monitor 94220534 foi alocado para a disciplina 939.
# Monitor 94220535 foi alocado para a disciplina 220.
# Monitor 94220537 foi alocado para a disciplina 230.
# Monitor 94220538 foi alocado para a disciplina 204.
# Monitor 94220540 foi alocado para a disciplina 83.
# Monitor 94220541 foi alocado para a disciplina 251.
# Monitor 94220542 foi alocado para a disciplina 287.
# Monitor 94220544 foi alocado para a disciplina 96.
# Monitor 94220547 foi alocado para a disciplina 961.
# Monitor 94220549 foi alocado para a disciplina 143.
# Monitor 94220550 foi alocado para a disciplina 1038.
# Monitor 94220552 foi alocado para a disciplina 676.
# Monitor 94220554 foi alocado para a disciplina 963.
# Monitor 94220556 foi alocado para a disciplina 449.
# Monitor 94220558 foi alocado para a disciplina 319.
# Monitor 94220559 foi alocado para a disciplina 237.
# Monitor 94220560 foi alocado para a disciplina 653.
# Monitor 94220561 foi alocado para a disciplina 707.
# Monitor 94220562 foi alocado para a disciplina 786.
# Monitor 94220563 foi alocado para a disciplina 157.
# Monitor 94220565 foi alocado para a disciplina 82.
# Monitor 94220567 foi alocado para a disciplina 483.
# Monitor 94220568 foi alocado para a disciplina 329.
# Monitor 94220569 foi alocado para a disciplina 789.
# Monitor 94220570 foi alocado para a disciplina 930.
# Monitor 94220571 foi alocado para a disciplina 355.
# Monitor 94220572 foi alocado para a disciplina 295.
# Monitor 94220575 foi alocado para a disciplina 299.
# Monitor 94220576 foi alocado para a disciplina 354.
# Monitor 94220577 foi alocado para a disciplina 234.
# Monitor 94220578 foi alocado para a disciplina 181.
# Monitor 94220579 foi alocado para a disciplina 601.
# Monitor 94220581 foi alocado para a disciplina 88.
# Monitor 94220582 foi alocado para a disciplina 938.
# Monitor 94220583 foi alocado para a disciplina 859.
# Monitor 94220585 foi alocado para a disciplina 632.
# Monitor 94220586 foi alocado para a disciplina 183.
# Monitor 94220587 foi alocado para a disciplina 1036.
# Monitor 94220588 foi alocado para a disciplina 196.
# Monitor 94220589 foi alocado para a disciplina 187.
# Monitor 94220590 foi alocado para a disciplina 568.
# Monitor 94220591 foi alocado para a disciplina 280.
# Monitor 94220593 foi alocado para a disciplina 418.
# Monitor 94220595 foi alocado para a disciplina 554.
# Monitor 94220596 foi alocado para a disciplina 293.
# Monitor 94220597 foi alocado para a disciplina 856.
# Monitor 94220598 foi alocado para a disciplina 1030.
# Monitor 94220599 foi alocado para a disciplina 935.
# Monitor 94220601 foi alocado para a disciplina 446.
# Monitor 94220605 foi alocado para a disciplina 669.
# Monitor 94220606 foi alocado para a disciplina 798.
# Monitor 94220607 foi alocado para a disciplina 1108.
# Monitor 94220608 foi alocado para a disciplina 851.
# Monitor 94220609 foi alocado para a disciplina 1096.
# Monitor 94220610 foi alocado para a disciplina 66.
# Monitor 94220613 foi alocado para a disciplina 1051.
# Monitor 94220615 foi alocado para a disciplina 536.
# Monitor 94220616 foi alocado para a disciplina 404.
# Monitor 94220617 foi alocado para a disciplina 484.
# Monitor 94220618 foi alocado para a disciplina 565.
# Monitor 94220619 foi alocado para a disciplina 609.
# Monitor 94220620 foi alocado para a disciplina 838.
# Monitor 94220621 foi alocado para a disciplina 993.
# Monitor 94220622 foi alocado para a disciplina 298.
# Monitor 94220623 foi alocado para a disciplina 392.
# Monitor 94220624 foi alocado para a disciplina 868.
# Monitor 94220626 foi alocado para a disciplina 716.
# Monitor 94220627 foi alocado para a disciplina 542.
# Monitor 94220628 foi alocado para a disciplina 1098.
# Monitor 94220629 foi alocado para a disciplina 612.
# Monitor 94220630 foi alocado para a disciplina 750.
# Monitor 94220631 foi alocado para a disciplina 87.
# Monitor 94220632 foi alocado para a disciplina 770.
# Monitor 94220633 foi alocado para a disciplina 498.
# Monitor 94220635 foi alocado para a disciplina 363.
# Monitor 94220637 foi alocado para a disciplina 120.
# Monitor 94220638 foi alocado para a disciplina 799.
# Monitor 94220639 foi alocado para a disciplina 495.
# Monitor 94220641 foi alocado para a disciplina 1063.
# Monitor 94220642 foi alocado para a disciplina 410.
# Monitor 94220643 foi alocado para a disciplina 485.
# Monitor 94220645 foi alocado para a disciplina 916.
# Monitor 94220646 foi alocado para a disciplina 1059.
# Monitor 94220648 foi alocado para a disciplina 992.
# Monitor 94220650 foi alocado para a disciplina 31.
# Monitor 94220651 foi alocado para a disciplina 63.
# Monitor 94220652 foi alocado para a disciplina 840.
# Monitor 94220653 foi alocado para a disciplina 511.
# Monitor 94220654 foi alocado para a disciplina 725.
# Monitor 94220655 foi alocado para a disciplina 746.
# Monitor 94220656 foi alocado para a disciplina 268.
# Monitor 94220657 foi alocado para a disciplina 486.
# Monitor 94220658 foi alocado para a disciplina 863.
# Monitor 94220659 foi alocado para a disciplina 349.
# Monitor 94220660 foi alocado para a disciplina 690.
# Monitor 94220662 foi alocado para a disciplina 535.
# Monitor 94220663 foi alocado para a disciplina 211.
# Monitor 94220665 foi alocado para a disciplina 1115.
# Monitor 94220666 foi alocado para a disciplina 336.
# Monitor 94220667 foi alocado para a disciplina 528.
# Monitor 94220668 foi alocado para a disciplina 775.
# Monitor 94220671 foi alocado para a disciplina 1033.
# Monitor 94220672 foi alocado para a disciplina 862.
# Monitor 94220673 foi alocado para a disciplina 642.
# Monitor 94220674 foi alocado para a disciplina 455.
# Monitor 94220675 foi alocado para a disciplina 971.
# Monitor 94220676 foi alocado para a disciplina 43.
# Monitor 94220677 foi alocado para a disciplina 373.
# Monitor 94220678 foi alocado para a disciplina 847.
# Monitor 94220679 foi alocado para a disciplina 753.
# Monitor 94220680 foi alocado para a disciplina 269.
# Monitor 94220681 foi alocado para a disciplina 571.
# Monitor 94220683 foi alocado para a disciplina 604.
# Monitor 94220684 foi alocado para a disciplina 919.
# Monitor 94220686 foi alocado para a disciplina 475.
# Monitor 94220687 foi alocado para a disciplina 890.
# Monitor 94220688 foi alocado para a disciplina 817.
# Monitor 94220689 foi alocado para a disciplina 1121.
# Monitor 94220690 foi alocado para a disciplina 709.
# Monitor 94220691 foi alocado para a disciplina 134.
# Monitor 94220692 foi alocado para a disciplina 771.
# Monitor 94220693 foi alocado para a disciplina 374.
# Monitor 94220694 foi alocado para a disciplina 362.
# Monitor 94220696 foi alocado para a disciplina 895.
# Monitor 94220697 foi alocado para a disciplina 1088.
# Monitor 94220698 foi alocado para a disciplina 239.
# Monitor 94220699 foi alocado para a disciplina 618.
# Monitor 94220702 foi alocado para a disciplina 139.
# Monitor 94220703 foi alocado para a disciplina 755.
# Monitor 94220705 foi alocado para a disciplina 346.
# Monitor 94220706 foi alocado para a disciplina 276.
# Monitor 94220708 foi alocado para a disciplina 886.
# Monitor 94220709 foi alocado para a disciplina 1026.
# Monitor 94220712 foi alocado para a disciplina 803.
# Monitor 94220714 foi alocado para a disciplina 1035.
# Monitor 94220716 foi alocado para a disciplina 381.
# Monitor 94220717 foi alocado para a disciplina 991.
# Monitor 94220718 foi alocado para a disciplina 719.
# Monitor 94220719 foi alocado para a disciplina 194.
# Monitor 94220720 foi alocado para a disciplina 657.
# Monitor 94220721 foi alocado para a disciplina 722.
# Monitor 94220722 foi alocado para a disciplina 562.
# Monitor 94220723 foi alocado para a disciplina 679.
# Monitor 94220724 foi alocado para a disciplina 326.
# Monitor 94220725 foi alocado para a disciplina 162.
# Monitor 94220726 foi alocado para a disciplina 853.
# Monitor 94220727 foi alocado para a disciplina 518.
# Monitor 94220728 foi alocado para a disciplina 408.
# Monitor 94220729 foi alocado para a disciplina 584.
# Monitor 94220732 foi alocado para a disciplina 1119.
# Monitor 94220733 foi alocado para a disciplina 747.
# Monitor 94220734 foi alocado para a disciplina 744.
# Monitor 94220736 foi alocado para a disciplina 846.
# Monitor 94220737 foi alocado para a disciplina 878.
# Monitor 94220738 foi alocado para a disciplina 129.
# Monitor 94220739 foi alocado para a disciplina 616.
# Monitor 94220740 foi alocado para a disciplina 202.
# Monitor 94220741 foi alocado para a disciplina 656.
# Monitor 94220742 foi alocado para a disciplina 245.
# Monitor 94220744 foi alocado para a disciplina 1023.
# Monitor 94220746 foi alocado para a disciplina 569.
# Monitor 94220748 foi alocado para a disciplina 972.
# Monitor 94220751 foi alocado para a disciplina 1006.
# Monitor 94220752 foi alocado para a disciplina 458.
# Monitor 94220753 foi alocado para a disciplina 197.
# Monitor 94220757 foi alocado para a disciplina 958.
# Monitor 94220759 foi alocado para a disciplina 748.
# Monitor 94220760 foi alocado para a disciplina 438.
# Monitor 94220762 foi alocado para a disciplina 879.
# Monitor 94220763 foi alocado para a disciplina 146.
# Monitor 94220764 foi alocado para a disciplina 921.
# Monitor 94220765 foi alocado para a disciplina 448.
# Monitor 94220766 foi alocado para a disciplina 910.
# Monitor 94220767 foi alocado para a disciplina 179.
# Monitor 94220769 foi alocado para a disciplina 682.
# Monitor 94220771 foi alocado para a disciplina 1072.
# Monitor 94220772 foi alocado para a disciplina 216.
# Monitor 94220773 foi alocado para a disciplina 231.
# Monitor 94220775 foi alocado para a disciplina 825.
# Monitor 94220776 foi alocado para a disciplina 546.
# Monitor 94220777 foi alocado para a disciplina 331.
# Monitor 94220778 foi alocado para a disciplina 1065.
# Monitor 94220779 foi alocado para a disciplina 185.
# Monitor 94220780 foi alocado para a disciplina 115.
# Monitor 94220781 foi alocado para a disciplina 133.
# Monitor 94220783 foi alocado para a disciplina 274.
# Monitor 94220785 foi alocado para a disciplina 552.
# Monitor 94220787 foi alocado para a disciplina 638.
# Monitor 94220789 foi alocado para a disciplina 650.
# Monitor 94220790 foi alocado para a disciplina 1012.
# Monitor 94220794 foi alocado para a disciplina 736.
# Monitor 94220795 foi alocado para a disciplina 429.
# Monitor 94220796 foi alocado para a disciplina 913.
# Monitor 94220797 foi alocado para a disciplina 264.
# Monitor 94220798 foi alocado para a disciplina 926.
# Monitor 94220799 foi alocado para a disciplina 675.
# Monitor 94220800 foi alocado para a disciplina 908.
# Monitor 94220801 foi alocado para a disciplina 574.
# Monitor 94220802 foi alocado para a disciplina 877.
# Monitor 94220803 foi alocado para a disciplina 265.
# Monitor 94220804 foi alocado para a disciplina 159.
# Monitor 94220805 foi alocado para a disciplina 1029.
# Monitor 94220806 foi alocado para a disciplina 248.
# Monitor 94220807 foi alocado para a disciplina 376.
# Monitor 94220809 foi alocado para a disciplina 193.
# Monitor 94220812 foi alocado para a disciplina 909.
# Monitor 94220815 foi alocado para a disciplina 1118.
# Monitor 94220816 foi alocado para a disciplina 703.
# Monitor 94220817 foi alocado para a disciplina 677.
# Monitor 94220818 foi alocado para a disciplina 986.
# Monitor 94220821 foi alocado para a disciplina 289.
# Monitor 94220822 foi alocado para a disciplina 797.
# Monitor 94220825 foi alocado para a disciplina 317.
# Monitor 94220826 foi alocado para a disciplina 611.
# Monitor 94220827 foi alocado para a disciplina 160.
# Monitor 94220828 foi alocado para a disciplina 927.
# Monitor 94220829 foi alocado para a disciplina 345.
# Monitor 94220830 foi alocado para a disciplina 496.
# Monitor 94220832 foi alocado para a disciplina 907.
# Monitor 94220833 foi alocado para a disciplina 970.
# Monitor 94220835 foi alocado para a disciplina 575.
# Monitor 94220838 foi alocado para a disciplina 380.
# Monitor 94220839 foi alocado para a disciplina 1097.
# Monitor 94220841 foi alocado para a disciplina 99.
# Monitor 94220842 foi alocado para a disciplina 124.
# Monitor 94220843 foi alocado para a disciplina 385.
# Monitor 94220846 foi alocado para a disciplina 622.
# Monitor 94220848 foi alocado para a disciplina 820.
# Monitor 94220850 foi alocado para a disciplina 359.
# Monitor 94220851 foi alocado para a disciplina 89.
# Monitor 94220852 foi alocado para a disciplina 358.
# Monitor 94220853 foi alocado para a disciplina 830.
# Monitor 94220854 foi alocado para a disciplina 652.
# Monitor 94220855 foi alocado para a disciplina 503.
# Monitor 94220856 foi alocado para a disciplina 937.
# Monitor 94220857 foi alocado para a disciplina 73.
# Monitor 94220859 foi alocado para a disciplina 113.
# Monitor 94220860 foi alocado para a disciplina 1019.
# Monitor 94220861 foi alocado para a disciplina 792.
# Monitor 94220862 foi alocado para a disciplina 94.
# Monitor 94220864 foi alocado para a disciplina 338.
# Monitor 94220865 foi alocado para a disciplina 1081.
# Monitor 94220866 foi alocado para a disciplina 852.
# Monitor 94220869 foi alocado para a disciplina 545.
# Monitor 94220870 foi alocado para a disciplina 1007.
# Monitor 94220874 foi alocado para a disciplina 800.
# Monitor 94220875 foi alocado para a disciplina 224.
# Monitor 94220876 foi alocado para a disciplina 1024.
# Monitor 94220877 foi alocado para a disciplina 367.
# Monitor 94220879 foi alocado para a disciplina 394.
# Monitor 94220880 foi alocado para a disciplina 671.
# Monitor 94220881 foi alocado para a disciplina 1037.
# Monitor 94220882 foi alocado para a disciplina 987.
# Monitor 94220883 foi alocado para a disciplina 580.
# Monitor 94220885 foi alocado para a disciplina 219.
# Monitor 94220886 foi alocado para a disciplina 100.
# Monitor 94220887 foi alocado para a disciplina 465.
# Monitor 94220888 foi alocado para a disciplina 333.
# Monitor 94220889 foi alocado para a disciplina 994.
# Monitor 94220890 foi alocado para a disciplina 699.
# Monitor 94220892 foi alocado para a disciplina 507.
# Monitor 94220893 foi alocado para a disciplina 686.
# Monitor 94220896 foi alocado para a disciplina 198.
# Monitor 94220897 foi alocado para a disciplina 520.
# Monitor 94220899 foi alocado para a disciplina 806.
# Monitor 94220900 foi alocado para a disciplina 631.
# Monitor 94220901 foi alocado para a disciplina 643.
# Monitor 94220902 foi alocado para a disciplina 256.
# Monitor 94220903 foi alocado para a disciplina 403.
# Monitor 94220904 foi alocado para a disciplina 456.
# Monitor 94220905 foi alocado para a disciplina 587.
# Monitor 94220909 foi alocado para a disciplina 767.
# Monitor 94220910 foi alocado para a disciplina 1018.
# Monitor 94220913 foi alocado para a disciplina 1073.
# Monitor 94220914 foi alocado para a disciplina 259.
# Monitor 94220915 foi alocado para a disciplina 1068.
# Monitor 94220916 foi alocado para a disciplina 629.
# Monitor 94220917 foi alocado para a disciplina 1052.
# Monitor 94220918 foi alocado para a disciplina 660.
# Monitor 94220919 foi alocado para a disciplina 222.
# Monitor 94220920 foi alocado para a disciplina 673.
# Monitor 94220921 foi alocado para a disciplina 635.
# Monitor 94220922 foi alocado para a disciplina 1058.
# Monitor 94220923 foi alocado para a disciplina 1054.
# Monitor 94220924 foi alocado para a disciplina 411.
# Monitor 94220925 foi alocado para a disciplina 602.
# Monitor 94220927 foi alocado para a disciplina 453.
# Monitor 94220928 foi alocado para a disciplina 974.
# Monitor 94220930 foi alocado para a disciplina 737.
# Monitor 94220931 foi alocado para a disciplina 975.
# Monitor 94220934 foi alocado para a disciplina 1005.
# Monitor 94220935 foi alocado para a disciplina 477.
# Monitor 94220936 foi alocado para a disciplina 778.
# Monitor 94220937 foi alocado para a disciplina 664.
# Monitor 94220938 foi alocado para a disciplina 434.
# Monitor 94220939 foi alocado para a disciplina 819.
# Monitor 94220941 foi alocado para a disciplina 583.
# Monitor 94220942 foi alocado para a disciplina 473.
# Monitor 94220943 foi alocado para a disciplina 1071.
# Monitor 94220944 foi alocado para a disciplina 783.
# Monitor 94220945 foi alocado para a disciplina 233.
# Monitor 94220947 foi alocado para a disciplina 368.
# Monitor 94220949 foi alocado para a disciplina 469.
# Monitor 94220954 foi alocado para a disciplina 752.
# Monitor 94220955 foi alocado para a disciplina 132.
# Monitor 94220958 foi alocado para a disciplina 732.
# Monitor 94220959 foi alocado para a disciplina 808.
# Monitor 94220960 foi alocado para a disciplina 531.
# Monitor 94220961 foi alocado para a disciplina 766.
# Monitor 94220963 foi alocado para a disciplina 500.
# Monitor 94220964 foi alocado para a disciplina 903.
# Monitor 94220965 foi alocado para a disciplina 592.
# Monitor 94220966 foi alocado para a disciplina 882.
# Monitor 94220967 foi alocado para a disciplina 1011.
# Monitor 94220968 foi alocado para a disciplina 634.
# Monitor 94220969 foi alocado para a disciplina 920.
# Monitor 94220970 foi alocado para a disciplina 466.
# Monitor 94220971 foi alocado para a disciplina 712.
# Monitor 94220972 foi alocado para a disciplina 639.
# Monitor 94220973 foi alocado para a disciplina 423.
# Monitor 94220974 foi alocado para a disciplina 464.
# Monitor 94220976 foi alocado para a disciplina 739.
# Monitor 94220977 foi alocado para a disciplina 811.
# Monitor 94220978 foi alocado para a disciplina 706.
# Monitor 94220980 foi alocado para a disciplina 413.
# Monitor 94220981 foi alocado para a disciplina 414.
# Monitor 94220982 foi alocado para a disciplina 212.
# Monitor 94220987 foi alocado para a disciplina 533.
# Monitor 94220989 foi alocado para a disciplina 1117.
# Monitor 94220990 foi alocado para a disciplina 258.
# Monitor 94220991 foi alocado para a disciplina 763.
# Monitor 94220992 foi alocado para a disciplina 1104.
# Monitor 94220993 foi alocado para a disciplina 661.
# Monitor 94220994 foi alocado para a disciplina 170.
# Monitor 94220995 foi alocado para a disciplina 843.
# Monitor 94220996 foi alocado para a disciplina 281.
# Monitor 94220999 foi alocado para a disciplina 1043.
# Monitor 94221000 foi alocado para a disciplina 514.
# Monitor 94221001 foi alocado para a disciplina 221.
# Monitor 94221002 foi alocado para a disciplina 76.
# Monitor 94221003 foi alocado para a disciplina 620.
# Monitor 94221004 foi alocado para a disciplina 801.
# Monitor 94221005 foi alocado para a disciplina 460.
# Monitor 94221007 foi alocado para a disciplina 506.
# Monitor 94221008 foi alocado para a disciplina 923.
# Monitor 94221009 foi alocado para a disciplina 980.
# Monitor 94221010 foi alocado para a disciplina 827.
# Monitor 94221011 foi alocado para a disciplina 342.
# Monitor 94221012 foi alocado para a disciplina 566.
# Monitor 94221013 foi alocado para a disciplina 433.
# Monitor 94221014 foi alocado para a disciplina 71.
# Monitor 94221015 foi alocado para a disciplina 98.
# Monitor 94221016 foi alocado para a disciplina 615.
# Monitor 94221017 foi alocado para a disciplina 861.
# Monitor 94221018 foi alocado para a disciplina 91.
# Monitor 94221020 foi alocado para a disciplina 572.
# Monitor 94221022 foi alocado para a disciplina 989.
# Monitor 94221023 foi alocado para a disciplina 1085.
# Monitor 94221024 foi alocado para a disciplina 266.
# Monitor 94221025 foi alocado para a disciplina 504.
# Monitor 94221026 foi alocado para a disciplina 888.
# Monitor 94221027 foi alocado para a disciplina 860.
# Monitor 94221028 foi alocado para a disciplina 284.
# Monitor 94221030 foi alocado para a disciplina 680.
# Monitor 94221031 foi alocado para a disciplina 1027.
# Monitor 94221032 foi alocado para a disciplina 491.
# Monitor 94221034 foi alocado para a disciplina 208.
# Monitor 94221035 foi alocado para a disciplina 435.
# Monitor 94221036 foi alocado para a disciplina 1070.
# Monitor 94221037 foi alocado para a disciplina 901.
# Monitor 94221038 foi alocado para a disciplina 246.
# Monitor 94221039 foi alocado para a disciplina 804.
# Monitor 94221041 foi alocado para a disciplina 777.
# Monitor 94221042 foi alocado para a disciplina 72.
# Monitor 94221043 foi alocado para a disciplina 870.
# Monitor 94221045 foi alocado para a disciplina 396.
# Monitor 94221046 foi alocado para a disciplina 904.
# Monitor 94221047 foi alocado para a disciplina 955.
# Monitor 94221050 foi alocado para a disciplina 922.
# Monitor 94221051 foi alocado para a disciplina 442.
# Monitor 94221052 foi alocado para a disciplina 818.
# Monitor 94221053 foi alocado para a disciplina 121.
# Monitor 94221054 foi alocado para a disciplina 379.
# Monitor 94221055 foi alocado para a disciplina 979.
# Monitor 94221056 foi alocado para a disciplina 1079.
# Monitor 94221057 foi alocado para a disciplina 407.
# Monitor 94221058 foi alocado para a disciplina 111.
# Monitor 94221059 foi alocado para a disciplina 527.
# Monitor 94221061 foi alocado para a disciplina 232.
# Monitor 94221062 foi alocado para a disciplina 1103.
# Monitor 94221063 foi alocado para a disciplina 1039.
# Monitor 94221064 foi alocado para a disciplina 227.
# Monitor 94221065 foi alocado para a disciplina 940.
# Monitor 94221066 foi alocado para a disciplina 836.
# Monitor 94221067 foi alocado para a disciplina 871.
# Monitor 94221068 foi alocado para a disciplina 171.
# Monitor 94221069 foi alocado para a disciplina 386.
# Monitor 94221070 foi alocado para a disciplina 1105.
# Monitor 94221071 foi alocado para a disciplina 581.
# Monitor 94221075 foi alocado para a disciplina 472.
# Monitor 94221076 foi alocado para a disciplina 186.
# Monitor 94221079 foi alocado para a disciplina 505.
# Monitor 94221081 foi alocado para a disciplina 810.
# Monitor 94221082 foi alocado para a disciplina 590.
# Monitor 94221083 foi alocado para a disciplina 417.
# Monitor 94221084 foi alocado para a disciplina 714.
# Monitor 94221085 foi alocado para a disciplina 207.
# Monitor 94221086 foi alocado para a disciplina 390.
# Monitor 94221087 foi alocado para a disciplina 891.
# Monitor 94221088 foi alocado para a disciplina 1000.
# Monitor 94221089 foi alocado para a disciplina 316.
# Monitor 94221090 foi alocado para a disciplina 845.
# Monitor 94221091 foi alocado para a disciplina 696.
# Monitor 94221092 foi alocado para a disciplina 1002.
# Monitor 94221094 foi alocado para a disciplina 140.
# Monitor 94221095 foi alocado para a disciplina 982.
# Monitor 94221096 foi alocado para a disciplina 857.
# Monitor 94221097 foi alocado para a disciplina 131.
# Monitor 94221099 foi alocado para a disciplina 1101.
# Monitor 94221100 foi alocado para a disciplina 988.
# Monitor 94221101 foi alocado para a disciplina 720.
# Monitor 94221103 foi alocado para a disciplina 768.
# Monitor 94221104 foi alocado para a disciplina 547.
# Monitor 94221106 foi alocado para a disciplina 444.
# Monitor 94221107 foi alocado para a disciplina 125.
# Monitor 94221108 foi alocado para a disciplina 147.
# Monitor 94221109 foi alocado para a disciplina 540.
# Monitor 94221111 foi alocado para a disciplina 1093.
# Monitor 94221112 foi alocado para a disciplina 432.
# Monitor 94221115 foi alocado para a disciplina 815.
# Monitor 94221117 foi alocado para a disciplina 556.
# Monitor 94221118 foi alocado para a disciplina 67.
# Monitor 94221121 foi alocado para a disciplina 226.
# Monitor 94221125 foi alocado para a disciplina 360.
# Monitor 94221126 foi alocado para a disciplina 1025.
# Monitor 94221127 foi alocado para a disciplina 440.
# Monitor 94221128 foi alocado para a disciplina 956.
# Monitor 94221129 foi alocado para a disciplina 641.
# ...
# Monitor 94220754 NÃO foi alocado. Inscrito para as disciplinas: [398, 696]
# Monitor 94220755 NÃO foi alocado. Inscrito para as disciplinas: [159, 964, 1072]
# Monitor 94220756 NÃO foi alocado. Inscrito para as disciplinas: [165, 277, 528, 955]
# Monitor 94220758 NÃO foi alocado. Inscrito para as disciplinas: [206, 225]
# Monitor 94220761 NÃO foi alocado. Inscrito para as disciplinas: [884, 995, 1009]
# Monitor 94220768 NÃO foi alocado. Inscrito para as disciplinas: [230, 238, 775]
# Monitor 94220770 NÃO foi alocado. Inscrito para as disciplinas: [325, 347, 382, 619]
# Monitor 94220774 NÃO foi alocado. Inscrito para as disciplinas: [192, 827]
# Monitor 94220782 NÃO foi alocado. Inscrito para as disciplinas: [203, 738, 889]
# Monitor 94220784 NÃO foi alocado. Inscrito para as disciplinas: [644, 703, 1016, 1120]
# Monitor 94220786 NÃO foi alocado. Inscrito para as disciplinas: [369, 400, 556, 1024]
# Monitor 94220788 NÃO foi alocado. Inscrito para as disciplinas: [932, 1085]
# Monitor 94220791 NÃO foi alocado. Inscrito para as disciplinas: [2, 53, 286, 986]
# Monitor 94220792 NÃO foi alocado. Inscrito para as disciplinas: [224, 283]
# Monitor 94220793 NÃO foi alocado. Inscrito para as disciplinas: [98, 128, 396]
# Monitor 94220808 NÃO foi alocado. Inscrito para as disciplinas: [78, 1056]
# Monitor 94220810 NÃO foi alocado. Inscrito para as disciplinas: [735, 749]
# Monitor 94220811 NÃO foi alocado. Inscrito para as disciplinas: [257, 687, 1000]
# Monitor 94220813 NÃO foi alocado. Inscrito para as disciplinas: [195, 266, 386]
# Monitor 94220814 NÃO foi alocado. Inscrito para as disciplinas: [346, 544, 564, 664]
# Monitor 94220819 NÃO foi alocado. Inscrito para as disciplinas: [120, 679, 706]
# Monitor 94220820 NÃO foi alocado. Inscrito para as disciplinas: [565, 938]
# Monitor 94220823 NÃO foi alocado. Inscrito para as disciplinas: [48, 227, 933]
# Monitor 94220824 NÃO foi alocado. Inscrito para as disciplinas: [318, 609, 674]
# Monitor 94220831 NÃO foi alocado. Inscrito para as disciplinas: [56, 392, 675, 770]
# Monitor 94220834 NÃO foi alocado. Inscrito para as disciplinas: [439, 690, 714, 810]
# Monitor 94220836 NÃO foi alocado. Inscrito para as disciplinas: [721, 774]
# Monitor 94220837 NÃO foi alocado. Inscrito para as disciplinas: [56, 343, 830]
# Monitor 94220840 NÃO foi alocado. Inscrito para as disciplinas: [200, 347, 927]
# Monitor 94220844 NÃO foi alocado. Inscrito para as disciplinas: [179, 408, 595, 1066]
# Monitor 94220845 NÃO foi alocado. Inscrito para as disciplinas: [1, 634, 684, 1119]
# Monitor 94220847 NÃO foi alocado. Inscrito para as disciplinas: [205, 615, 708]
# Monitor 94220849 NÃO foi alocado. Inscrito para as disciplinas: [881, 952]
# Monitor 94220858 NÃO foi alocado. Inscrito para as disciplinas: [294, 624, 675]
# Monitor 94220863 NÃO foi alocado. Inscrito para as disciplinas: [160, 459, 818, 995]
# Monitor 94220867 NÃO foi alocado. Inscrito para as disciplinas: [91, 282, 1054]
# Monitor 94220868 NÃO foi alocado. Inscrito para as disciplinas: [122, 553, 853]
# Monitor 94220871 NÃO foi alocado. Inscrito para as disciplinas: [220, 583, 735]
# Monitor 94220872 NÃO foi alocado. Inscrito para as disciplinas: [408, 476, 493]
# Monitor 94220873 NÃO foi alocado. Inscrito para as disciplinas: [249, 514, 1095]
# Monitor 94220878 NÃO foi alocado. Inscrito para as disciplinas: [356, 506, 603, 995]
# Monitor 94220884 NÃO foi alocado. Inscrito para as disciplinas: [135, 139, 363, 949]
# Monitor 94220891 NÃO foi alocado. Inscrito para as disciplinas: [44, 210, 306, 685]
# Monitor 94220894 NÃO foi alocado. Inscrito para as disciplinas: [530, 696, 827, 1049]
# Monitor 94220895 NÃO foi alocado. Inscrito para as disciplinas: [135, 533, 696, 921]
# Monitor 94220898 NÃO foi alocado. Inscrito para as disciplinas: [496, 658, 722, 741]
# Monitor 94220906 NÃO foi alocado. Inscrito para as disciplinas: [328, 437, 927]
# Monitor 94220907 NÃO foi alocado. Inscrito para as disciplinas: [101, 341]
# Monitor 94220908 NÃO foi alocado. Inscrito para as disciplinas: [459, 463]
# Monitor 94220911 NÃO foi alocado. Inscrito para as disciplinas: [201, 475]
# Monitor 94220912 NÃO foi alocado. Inscrito para as disciplinas: [187, 888]
# Monitor 94220926 NÃO foi alocado. Inscrito para as disciplinas: [186, 314, 788, 934]
# Monitor 94220929 NÃO foi alocado. Inscrito para as disciplinas: [106, 353, 514, 737]
# Monitor 94220932 NÃO foi alocado. Inscrito para as disciplinas: [553, 620, 653, 655]
# Monitor 94220933 NÃO foi alocado. Inscrito para as disciplinas: [40, 355, 919]
# Monitor 94220940 NÃO foi alocado. Inscrito para as disciplinas: [527, 866]
# Monitor 94220946 NÃO foi alocado. Inscrito para as disciplinas: [306, 493, 640, 1103]
# Monitor 94220948 NÃO foi alocado. Inscrito para as disciplinas: [605, 738]
# Monitor 94220950 NÃO foi alocado. Inscrito para as disciplinas: [205, 278, 337, 676]
# Monitor 94220951 NÃO foi alocado. Inscrito para as disciplinas: [160, 285, 317, 333]
# Monitor 94220952 NÃO foi alocado. Inscrito para as disciplinas: [796, 834]
# Monitor 94220953 NÃO foi alocado. Inscrito para as disciplinas: [32, 485, 705]
# Monitor 94220956 NÃO foi alocado. Inscrito para as disciplinas: [307, 435, 516, 1073]
# Monitor 94220957 NÃO foi alocado. Inscrito para as disciplinas: [228, 1035]
# Monitor 94220962 NÃO foi alocado. Inscrito para as disciplinas: [304, 423, 720, 847]
# Monitor 94220975 NÃO foi alocado. Inscrito para as disciplinas: [272, 408, 519, 792]
# Monitor 94220979 NÃO foi alocado. Inscrito para as disciplinas: [493, 533, 813]
# Monitor 94220983 NÃO foi alocado. Inscrito para as disciplinas: [267, 629]
# Monitor 94220984 NÃO foi alocado. Inscrito para as disciplinas: [122, 326]
# Monitor 94220985 NÃO foi alocado. Inscrito para as disciplinas: [380, 580, 586]
# Monitor 94220986 NÃO foi alocado. Inscrito para as disciplinas: [220, 533, 760, 847]
# Monitor 94220988 NÃO foi alocado. Inscrito para as disciplinas: [468, 650, 868, 991]
# Monitor 94220997 NÃO foi alocado. Inscrito para as disciplinas: [350, 441, 787, 891]
# Monitor 94220998 NÃO foi alocado. Inscrito para as disciplinas: [23, 1069]
# Monitor 94221006 NÃO foi alocado. Inscrito para as disciplinas: [110, 957, 976, 1120]
# Monitor 94221019 NÃO foi alocado. Inscrito para as disciplinas: [28, 201, 242, 1076]
# Monitor 94221021 NÃO foi alocado. Inscrito para as disciplinas: [249, 318]
# Monitor 94221029 NÃO foi alocado. Inscrito para as disciplinas: [791, 934, 982]
# Monitor 94221033 NÃO foi alocado. Inscrito para as disciplinas: [425, 655, 660]
# Monitor 94221040 NÃO foi alocado. Inscrito para as disciplinas: [123, 333, 851, 871]
# Monitor 94221044 NÃO foi alocado. Inscrito para as disciplinas: [152, 505, 996]
# Monitor 94221048 NÃO foi alocado. Inscrito para as disciplinas: [18, 725, 818, 1068]
# Monitor 94221049 NÃO foi alocado. Inscrito para as disciplinas: [53, 946, 1042]
# Monitor 94221060 NÃO foi alocado. Inscrito para as disciplinas: [136, 267, 766]
# Monitor 94221072 NÃO foi alocado. Inscrito para as disciplinas: [269, 582, 750, 786]
# Monitor 94221073 NÃO foi alocado. Inscrito para as disciplinas: [423, 602, 615, 917]
# Monitor 94221074 NÃO foi alocado. Inscrito para as disciplinas: [21, 341, 893]
# Monitor 94221077 NÃO foi alocado. Inscrito para as disciplinas: [769, 805]
# Monitor 94221078 NÃO foi alocado. Inscrito para as disciplinas: [484, 1032]
# Monitor 94221080 NÃO foi alocado. Inscrito para as disciplinas: [474, 924]
# Monitor 94221093 NÃO foi alocado. Inscrito para as disciplinas: [597, 602, 1102]
# Monitor 94221098 NÃO foi alocado. Inscrito para as disciplinas: [277, 428, 585, 1076]
# Monitor 94221102 NÃO foi alocado. Inscrito para as disciplinas: [94, 509]
# Monitor 94221105 NÃO foi alocado. Inscrito para as disciplinas: [38, 96, 137, 515]
# Monitor 94221110 NÃO foi alocado. Inscrito para as disciplinas: [163, 306]
# Monitor 94221113 NÃO foi alocado. Inscrito para as disciplinas: [137, 724]
# Monitor 94221114 NÃO foi alocado. Inscrito para as disciplinas: [520, 867, 1041]
# Monitor 94221116 NÃO foi alocado. Inscrito para as disciplinas: [100, 836]
# Monitor 94221119 NÃO foi alocado. Inscrito para as disciplinas: [187, 229, 583]
# Monitor 94221120 NÃO foi alocado. Inscrito para as disciplinas: [218, 866]
# Monitor 94221122 NÃO foi alocado. Inscrito para as disciplinas: [110, 547, 748]
# Monitor 94221123 NÃO foi alocado. Inscrito para as disciplinas: [14, 573, 742]
# Monitor 94221124 NÃO foi alocado. Inscrito para as disciplinas: [155, 418, 451]
# Monitor 94221134 NÃO foi alocado. Inscrito para as disciplinas: [95, 129, 212]
# Monitor 94221140 NÃO foi alocado. Inscrito para as disciplinas: [99, 192, 743]
# Monitor 94221142 NÃO foi alocado. Inscrito para as disciplinas: [419, 424]
# Monitor 94221144 NÃO foi alocado. Inscrito para as disciplinas: [19, 121, 694]
# Monitor 94221151 NÃO foi alocado. Inscrito para as disciplinas: [340, 363]
# Monitor 94221153 NÃO foi alocado. Inscrito para as disciplinas: [963, 1042]
# Monitor 94221162 NÃO foi alocado. Inscrito para as disciplinas: [305, 812, 842]
# Monitor 94221172 NÃO foi alocado. Inscrito para as disciplinas: [14, 269, 995, 1011]
# Monitor 94221181 NÃO foi alocado. Inscrito para as disciplinas: [699, 893, 932]
# Monitor 94221183 NÃO foi alocado. Inscrito para as disciplinas: [13, 47, 719, 725]
# Monitor 94221191 NÃO foi alocado. Inscrito para as disciplinas: [497, 1004]
# Monitor 94221199 NÃO foi alocado. Inscrito para as disciplinas: [787, 972]
# Monitor 94221202 NÃO foi alocado. Inscrito para as disciplinas: [450, 728, 797, 1035]
# Monitor 94221210 NÃO foi alocado. Inscrito para as disciplinas: [370, 617, 1011]
# Monitor 94221214 NÃO foi alocado. Inscrito para as disciplinas: [841, 994]
# Monitor 94221216 NÃO foi alocado. Inscrito para as disciplinas: [210, 242, 612, 981]
# Monitor 94221219 NÃO foi alocado. Inscrito para as disciplinas: [27, 763, 1101]
# Monitor 94221222 NÃO foi alocado. Inscrito para as disciplinas: [87, 104, 393]
# Monitor 94221224 NÃO foi alocado. Inscrito para as disciplinas: [229, 248]
# Monitor 94221226 NÃO foi alocado. Inscrito para as disciplinas: [243, 862]
# Monitor 94221228 NÃO foi alocado. Inscrito para as disciplinas: [162, 174, 213, 215]
# Monitor 94221229 NÃO foi alocado. Inscrito para as disciplinas: [521, 937]
# Monitor 94221236 NÃO foi alocado. Inscrito para as disciplinas: [40, 921]
# Monitor 94221240 NÃO foi alocado. Inscrito para as disciplinas: [15, 516, 1031]
# Monitor 94221241 NÃO foi alocado. Inscrito para as disciplinas: [647, 1037]
# Monitor 94221242 NÃO foi alocado. Inscrito para as disciplinas: [751, 800]
# Monitor 94221244 NÃO foi alocado. Inscrito para as disciplinas: [100, 181, 215, 448]
# Monitor 94221260 NÃO foi alocado. Inscrito para as disciplinas: [149, 629, 824]
# Monitor 94221266 NÃO foi alocado. Inscrito para as disciplinas: [128, 151, 636]
# Monitor 94221279 NÃO foi alocado. Inscrito para as disciplinas: [403, 854]
# Monitor 94221285 NÃO foi alocado. Inscrito para as disciplinas: [605, 956, 1014]
# Monitor 94221291 NÃO foi alocado. Inscrito para as disciplinas: [263, 849, 935]
# Monitor 94221295 NÃO foi alocado. Inscrito para as disciplinas: [166, 939]
# Monitor 94221301 NÃO foi alocado. Inscrito para as disciplinas: [0, 271]
# Monitor 94221302 NÃO foi alocado. Inscrito para as disciplinas: [1, 261, 590, 1104]
# Monitor 94221305 NÃO foi alocado. Inscrito para as disciplinas: [314, 451]
# Monitor 94221306 NÃO foi alocado. Inscrito para as disciplinas: [604, 626, 915, 976]
# Monitor 94221307 NÃO foi alocado. Inscrito para as disciplinas: [276, 945]
# Monitor 94221313 NÃO foi alocado. Inscrito para as disciplinas: [65, 141, 360, 516]
# Monitor 94221315 NÃO foi alocado. Inscrito para as disciplinas: [421, 509, 677]
# Monitor 94221328 NÃO foi alocado. Inscrito para as disciplinas: [463, 1013]
# Monitor 94221335 NÃO foi alocado. Inscrito para as disciplinas: [50, 162, 495, 751]
# Monitor 94221339 NÃO foi alocado. Inscrito para as disciplinas: [275, 641]
# Monitor 94221357 NÃO foi alocado. Inscrito para as disciplinas: [602, 609]
# Monitor 94221364 NÃO foi alocado. Inscrito para as disciplinas: [263, 523, 532, 678]
# Monitor 94221368 NÃO foi alocado. Inscrito para as disciplinas: [245, 1062]
# Monitor 94221369 NÃO foi alocado. Inscrito para as disciplinas: [390, 604, 887, 1032]
# Monitor 94221370 NÃO foi alocado. Inscrito para as disciplinas: [437, 856, 979]
# Monitor 94221371 NÃO foi alocado. Inscrito para as disciplinas: [442, 749]
# Monitor 94221374 NÃO foi alocado. Inscrito para as disciplinas: [103, 677]
# Monitor 94221375 NÃO foi alocado. Inscrito para as disciplinas: [225, 1087]
# Monitor 94221376 NÃO foi alocado. Inscrito para as disciplinas: [243, 300]
# Monitor 94221381 NÃO foi alocado. Inscrito para as disciplinas: [319, 970]
# Monitor 94221382 NÃO foi alocado. Inscrito para as disciplinas: [444, 608]
# Monitor 94221383 NÃO foi alocado. Inscrito para as disciplinas: [455, 921, 993]
# Monitor 94221385 NÃO foi alocado. Inscrito para as disciplinas: [216, 802, 856, 859]
# Monitor 94221388 NÃO foi alocado. Inscrito para as disciplinas: [674, 892]
# Monitor 94221391 NÃO foi alocado. Inscrito para as disciplinas: [86, 650]
# Monitor 94221402 NÃO foi alocado. Inscrito para as disciplinas: [225, 849, 854, 1031]
# Monitor 94221407 NÃO foi alocado. Inscrito para as disciplinas: [264, 582, 917]
# Monitor 94221410 NÃO foi alocado. Inscrito para as disciplinas: [443, 466, 682]
# Monitor 94221411 NÃO foi alocado. Inscrito para as disciplinas: [624, 958, 1004]
# Monitor 94221414 NÃO foi alocado. Inscrito para as disciplinas: [340, 593, 968, 1068]
# Monitor 94221419 NÃO foi alocado. Inscrito para as disciplinas: [73, 279, 544]
# Monitor 94221422 NÃO foi alocado. Inscrito para as disciplinas: [246, 895, 908]
#
# Disciplinas não atendidas e seus inscritos:
# A disciplina 108 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 127 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 130 não foi atendida por nenhum monitor. Inscritos: [94220236]
# A disciplina 148 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 150 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 161 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 169 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 184 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 190 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 236 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 244 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 292 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 339 não foi atendida por nenhum monitor. Inscritos: [94220113]
# A disciplina 383 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 388 não foi atendida por nenhum monitor. Inscritos: [94220470]
# A disciplina 457 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 501 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 502 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 538 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 539 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 550 não foi atendida por nenhum monitor. Inscritos: [94221075]
# A disciplina 591 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 614 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 757 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 781 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 831 não foi atendida por nenhum monitor. Inscritos: [94220146]
# A disciplina 880 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 951 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 954 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 967 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 990 não foi atendida por nenhum monitor. Inscritos: [94220570]
# A disciplina 1086 não foi atendida por nenhum monitor e não possui inscritos.
# A disciplina 1100 não foi atendida por nenhum monitor e não possui inscritos.
